# %%
# !pip install pandas sqlalchemy psycopg2-binary

# %%
# !nvidia-smi

# %%
import sys
sys.executable

# %%
# !pip uninstall torch torchvision torchaudio -y

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# CUDA version: 12.1
# GPU name: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %% [markdown]
# #### creating connection to database

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:2818@localhost:5432/youtube_trending_db"
)

# %% [markdown]
# #### importing files from database

# %%
df1 = pd.read_sql("SELECT * FROM youtube_trending_au", engine)
df2 = pd.read_sql("SELECT * FROM youtube_trending_ca", engine)
df3 = pd.read_sql("SELECT * FROM youtube_trending_gb", engine)
df4 = pd.read_sql("SELECT * FROM youtube_trending_ie", engine)
df5 = pd.read_sql("SELECT * FROM youtube_trending_in", engine)
df6 = pd.read_sql("SELECT * FROM youtube_trending_nz", engine)
df7 = pd.read_sql("SELECT * FROM youtube_trending_sg", engine)
df8 = pd.read_sql("SELECT * FROM youtube_trending_us", engine)
df9 = pd.read_sql("SELECT * FROM youtube_trending_za", engine)

# %%
df5 = pd.read_sql("SELECT * FROM youtube_trending_in", engine)

# %%
df5.describe()
# Out:
#                   video_published_at           channel_published_at  \
# count                          71153                          45315
# mean   2025-06-15 03:08:46.178123008  2014-08-11 16:53:49.332318464
# min              2024-10-05 09:30:06            2005-06-16 12:09:27
# 25%              2025-02-25 10:25:14            2012-02-02 15:11:49
# 50%              2025-07-04 12:58:48            2015-08-19 13:05:02
# 75%              2025-10-06 10:36:13            2017-09-10 18:22:11
# max              2026-01-05 17:54:37            2019-10-08 06:04:47
# std                              NaN                            NaN
#
#        video_view_count  video_like_count  video_comment_count  \
# count      7.115300e+04      7.115300e+04         7.115300e+04
# mean       1.721006e+06      5.305279e+04         3.135179e+03
# min        3.855000e+03      0.000000e+00         0.000000e+00
# 25%        1.601870e+05      2.663000e+03         6.400000e+01
# 50%        4.317670e+05      9.559000e+03         3.640000e+02
# 75%        1.237437e+06      3.778200e+04         1.596000e+03
# max        1.461346e+08      8.128232e+06         3.692689e+06
# std        5.023016e+06      1.907011e+05         3.118820e+04
#
#        channel_view_count  channel_subscriber_count  channel_video_count
# count        7.115300e+04              7.115300e+04         71153.000000
# mean         8.344613e+09              1.124459e+07         14420.071114
# min          0.000000e+00              3.000000e+00             0.000000
# 25%          1.150871e+08              5.380000e+05           269.000000
# 50%          6.423140e+08              2.150000e+06           913.000000
# 75%          3.479606e+09              9.310000e+06          3391.000000
# max          3.259206e+11              4.150000e+08        605562.000000
# std          2.792752e+10              2.954040e+07         39953.556593

# %%
df5["video_published_at"] = pd.to_datetime(df5["video_published_at"]).dt.normalize()
df5["video_trending_date"] = pd.to_datetime(df5["video_trending_date"]).dt.normalize()

# %%
print(df5.shape)
# Out:
# (71153, 28)

# %%
df5.head()
# Out:
#       video_id video_published_at video_trending_date  \
# 0  NCv-wz1nSnE         2024-10-12          2024-10-12
# 1  6YMY62tMLUA         2024-10-09          2024-10-12
# 2  uXhswFYwz5Y         2024-10-11          2024-10-12
# 3  nOhpsRj4M80         2024-10-11          2024-10-12
# 4  MD7v0-igVIM         2024-10-07          2024-10-12
#
#                  channel_id   channel_title  \
# 0  UCmse5JbKneJqVyerfhDVYvQ    UV Creations
# 1  UCq-Fj5jknLsUf-MWSy4_brA        T-Series
# 2  UCpZBvTbjam0yTrD4HUUWTZw  Oneindia Tamil
# 3  UCEeEQxm6qc_qaTE7qTV5aLQ          HUM TV
# 4  UCcXQd6kHKm0b41x8zMVMmMg      JioStudios
#
#                                  channel_description channel_custom_url  \
# 0  UV Creations, founded in 2012 by V Vamsikrishn...       @uvcreations
# 1  "Music can change the world". T-Series is Indi...           @tseries
# 2  Welcome to ‘Oneindia Tamil’, a Tamil YouTube c...     @oneindiatamil
# 3  HUM TV is Pakistan’s Premier Entertainment cha...             @humtv
# 4  Official Account of JioStudios\n\nwebsite : ht...        @jiostudios
#
#   channel_published_at channel_country  \
# 0  2014-04-10 16:49:33           India
# 1  2006-03-13 14:27:05           India
# 2  2014-01-29 04:52:25           India
# 3  2011-05-25 15:15:07        Pakistan
# 4  2018-11-05 06:07:05           India
#
#                                          video_title  ... video_view_count  \
# 0  VISHWAMBHARA Official Teaser | Megastar Chiran...  ...         18908234
# 1  Bhool Bhulaiyaa 3 (Official Trailer): Kartik A...  ...         56032799
# 2  Ratan Tata உடல் ஏன் பறவைகளுக்கு இரையாக்கப்படவி...  ...          1171952
# 3  Jafaa - Ep 21 [CC] - 11th Oct 2024 - Sponsored...  ...          7114713
# 4  Singham Again | Official Trailer | A Rohit She...  ...         40832089
#
#   video_like_count video_comment_count channel_view_count  \
# 0           236311               13573          744568146
# 1          1058449               44767       269373477007
# 2             8329                 336          720755351
# 3           122920                2690        36922121097
# 4           951141               83563          490715330
#
#   channel_subscriber_count channel_have_hidden_subscribers  \
# 0                  1570000                           False
# 1                276000000                           False
# 2                  3490000                           False
# 3                 43300000                           False
# 4                   794000                           False
#
#   channel_video_count  channel_localized_title  \
# 0                1023             UV Creations
# 1               21864                 T-Series
# 2               30160           Oneindia Tamil
# 3              155478                   HUM TV
# 4                 623               JioStudios
#
#                        channel_localized_description  video_trending_country
# 0  UV Creations, founded in 2012 by V Vamsikrishn...                   India
# 1  "Music can change the world". T-Series is Indi...                   India
# 2  Welcome to ‘Oneindia Tamil’, a Tamil YouTube c...                   India
# 3  HUM TV is Pakistan’s Premier Entertainment cha...                   India
# 4  Official Account of JioStudios\n\nwebsite : ht...                   India
#
# [5 rows x 28 columns]

# %%
df5.columns
# Out:
# Index(['video_id', 'video_published_at', 'video_trending_date', 'channel_id',
#        'channel_title', 'channel_description', 'channel_custom_url',
#        'channel_published_at', 'channel_country', 'video_title',
#        'video_description', 'video_default_thumbnail', 'video_category_id',
#        'video_tags', 'video_duration', 'video_dimension', 'video_definition',
#        'video_licensed_content', 'video_view_count', 'video_like_count',
#        'video_comment_count', 'channel_view_count', 'channel_subscriber_count',
#        'channel_have_hidden_subscribers', 'channel_video_count',
#        'channel_localized_title', 'channel_localized_description',
#        'video_trending_country'],
#       dtype='object')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71153 entries, 0 to 71152
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   video_id                         71153 non-null  object
#  1   video_published_at               71153 non-null  datetime64[ns]
#  2   video_trending_date              71153 non-null  datetime64[ns]
#  3   channel_id                       71153 non-null  object
#  4   channel_title                    71153 non-null  object
#  5   channel_description              65052 non-null  object
#  6   channel_custom_url               70574 non-null  object
#  7   channel_published_at             45315 non-null  datetime64[ns]
#  8   channel_country                  63023 non-null  object
#  9   video_title                      71153 non-null  object
#  10  video_description                69301 non-null  object
#  11  video_default_thumbnail          71153 non-null  object
#  12  video_category_id                71147 non-null  object
#  13  video_tags                       60089 non-null  object
#  14  video_duration                   71153 non-null  object
#  15  video_dimension                  71153 non-null  object
#  16  video_definition                 71153 non-null  object
#  17  video_licensed_content           71153 non-null  bool
#  18  video_view_count                 71153 non-null  int64
#  19  video_like_count                 71153 non-null  int64
#  20  video_comment_count              71153 non-null  int64
#  21  channel_view_count               71153 non-null  int64
#  22  channel_subscriber_count         71153 non-null  int64
#  23  channel_have_hidden_subscribers  71153 non-null  bool
#  24  channel_video_count              71153 non-null  int64
#  25  channel_localized_title          71153 non-null  object
#  26  channel_localized_description    65052 non-null  object
#  27  video_trending_country           71153 non-null  object
# dtypes: bool(2), datetime64[ns](3), int64(6), object(17)
# memory usage: 14.3+ MB

# %% [markdown]
# #### checking duplicates based on video_id

# %%
df5[df5['video_id'].duplicated(keep=False)].sort_values('video_id')
# Out:
#           video_id video_published_at video_trending_date  \
# 22547  --16EpBdvIU         2025-03-26          2025-03-31
# 22333  --16EpBdvIU         2025-03-26          2025-03-30
# 21970  --16EpBdvIU         2025-03-26          2025-03-28
# 22135  --16EpBdvIU         2025-03-26          2025-03-29
# 21804  --16EpBdvIU         2025-03-26          2025-03-27
# ...            ...                ...                 ...
# 35089  zzRgmpIwIXI         2025-06-30          2025-07-03
# 34758  zzRgmpIwIXI         2025-06-30          2025-07-01
# 58543  zz_kh-VjvrM         2025-11-02          2025-11-03
# 58802  zz_kh-VjvrM         2025-11-02          2025-11-04
# 58321  zz_kh-VjvrM         2025-11-02          2025-11-02
#
#                      channel_id                channel_title  \
# 22547  UCiKNX0TIMyKgGqQznhR1Xig  LOL (Life of Limbachiyaa’s)
# 22333  UCiKNX0TIMyKgGqQznhR1Xig  LOL (Life of Limbachiyaa’s)
# 21970  UCiKNX0TIMyKgGqQznhR1Xig  LOL (Life of Limbachiyaa’s)
# 22135  UCiKNX0TIMyKgGqQznhR1Xig  LOL (Life of Limbachiyaa’s)
# 21804  UCiKNX0TIMyKgGqQznhR1Xig  LOL (Life of Limbachiyaa’s)
# ...                         ...                          ...
# 35089  UC4Zgm_UaEwZqvdrzwvh_O2A              Flowers  Promos
# 34758  UC4Zgm_UaEwZqvdrzwvh_O2A              Flowers  Promos
# 58543  UCWRmZvwkp6oNca2wW3uFcFg                       SATVIK
# 58802  UCWRmZvwkp6oNca2wW3uFcFg                       SATVIK
# 58321  UCWRmZvwkp6oNca2wW3uFcFg                       SATVIK
#
#                                      channel_description  \
# 22547  Hello guys! We are Bharti Singh and Haarsh Lim...
# 22333  Hello guys! We are Bharti Singh and Haarsh Lim...
# 21970  Hello guys! We are Bharti Singh and Haarsh Lim...
# 22135  Hello guys! We are Bharti Singh and Haarsh Lim...
# 21804  Hello guys! We are Bharti Singh and Haarsh Lim...
# ...                                                  ...
# 35089  \n\nJoin us on \nFacebook- https://www.faceboo...
# 34758  \n\nJoin us on \nFacebook- https://www.faceboo...
# 58543  Hi, guys! I'm Satvik. This channel is speciall...
# 58802  Hi, guys! I'm Satvik. This channel is speciall...
# 58321  Hi, guys! I'm Satvik. This channel is speciall...
#
#          channel_custom_url channel_published_at channel_country  \
# 22547   @lifeoflimbachiyaas                  NaT           India
# 22333   @lifeoflimbachiyaas                  NaT           India
# 21970   @lifeoflimbachiyaas                  NaT           India
# 22135   @lifeoflimbachiyaas                  NaT           India
# 21804   @lifeoflimbachiyaas                  NaT           India
# ...                     ...                  ...             ...
# 35089  @flowerstvpromos4093                  NaT           India
# 34758  @flowerstvpromos4093                  NaT           India
# 58543               @satvik                  NaT           India
# 58802               @satvik                  NaT           India
# 58321               @satvik                  NaT           India
#
#                                              video_title  ...  \
# 22547  First Time Manisha Ka Makeover 😱 | Bharti Sing...  ...
# 22333  First Time Manisha Ka Makeover 😱 | Bharti Sing...  ...
# 21970  First Time Manisha Ka Makeover 😱 | Bharti Sing...  ...
# 22135  First Time Manisha Ka Makeover 😱 | Bharti Sing...  ...
# 21804  First Time Manisha Ka Makeover 😱 | Bharti Sing...  ...
# ...                                                  ...  ...
# 35089  ശിവാനിയുടെ കല്യാണപ്പന്തലിൽ ഞെട്ടിത്തരിക്കുന്ന ...  ...
# 34758  ശിവാനിയുടെ കല്യാണപ്പന്തലിൽ ഞെട്ടിത്തരിക്കുന്ന ...  ...
# 58543   SATVIK PRANKED DESI GAMERS AMITBHAI & _____ BHAI  ...
# 58802   SATVIK PRANKED DESI GAMERS AMITBHAI & _____ BHAI  ...
# 58321   SATVIK PRANKED DESI GAMERS AMITBHAI & _____ BHAI  ...
#
#       video_view_count video_like_count video_comment_count  \
# 22547          2012228            79613                2993
# 22333          1908183            77261                2929
# 21970          1535441            67782                2673
# 22135          1766639            73798                2838
# 21804          1276582            60071                2423
# ...                ...              ...                 ...
# 35089           935654             9310                 502
# 34758           789565             8882                 502
# 58543           709153            19466                1584
# 58802           832835            21510                1850
# 58321           482431            15338                1320
#
#       channel_view_count channel_subscriber_count  \
# 22547         3489139265                  7140000
# 22333         3486993645                  7140000
# 21970         3481692967                  7130000
# 22135         3484469796                  7140000
# 21804         3478529523                  7130000
# ...                  ...                      ...
# 35089          361196502                   347000
# 34758          360446986                   347000
# 58543         3731199665                 11500000
# 58802         3737231281                 11500000
# 58321         3725885736                 11500000
#
#       channel_have_hidden_subscribers channel_video_count  \
# 22547                           False                1587
# 22333                           False                1586
# 21970                           False                1583
# 22135                           False                1584
# 21804                           False                1581
# ...                               ...                 ...
# 35089                           False               11934
# 34758                           False               11919
# 58543                           False                 897
# 58802                           False                 897
# 58321                           False                 898
#
#            channel_localized_title  \
# 22547  LOL (Life of Limbachiyaa’s)
# 22333  LOL (Life of Limbachiyaa’s)
# 21970  LOL (Life of Limbachiyaa’s)
# 22135  LOL (Life of Limbachiyaa’s)
# 21804  LOL (Life of Limbachiyaa’s)
# ...                            ...
# 35089              Flowers  Promos
# 34758              Flowers  Promos
# 58543                       SATVIK
# 58802                       SATVIK
# 58321                       SATVIK
#
#                            channel_localized_description  \
# 22547  Hello guys! We are Bharti Singh and Haarsh Lim...
# 22333  Hello guys! We are Bharti Singh and Haarsh Lim...
# 21970  Hello guys! We are Bharti Singh and Haarsh Lim...
# 22135  Hello guys! We are Bharti Singh and Haarsh Lim...
# 21804  Hello guys! We are Bharti Singh and Haarsh Lim...
# ...                                                  ...
# 35089  \n\nJoin us on \nFacebook- https://www.faceboo...
# 34758  \n\nJoin us on \nFacebook- https://www.faceboo...
# 58543  Hi, guys! I'm Satvik. This channel is speciall...
# 58802  Hi, guys! I'm Satvik. This channel is speciall...
# 58321  Hi, guys! I'm Satvik. This channel is speciall...
#
#        video_trending_country
# 22547                   India
# 22333                   India
# 21970                   India
# 22135                   India
# 21804                   India
# ...                       ...
# 35089                   India
# 34758                   India
# 58543                   India
# 58802                   India
# 58321                   India
#
# [57241 rows x 28 columns]

# %%
df5 = df5.sort_values('video_trending_date')

# %% [markdown]
# #### considering only first day of trending

# %%
df5 = df5.drop_duplicates(
    subset='video_id',
    keep='first'
)

# %%
df5.duplicated("video_id").sum()
# Out:
# np.int64(0)

# %%
df5.shape
# Out:
# (32329, 28)

# %%
df5['video_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### creating target columns

# %%
df5["days_to_trend"] = (
    df5["video_trending_date"] - df5["video_published_at"]
).dt.days

# %%
df5.head()
# Out:
#        video_id video_published_at video_trending_date  \
# 0   NCv-wz1nSnE         2024-10-12          2024-10-12
# 98  dBa1_GKAOAk         2024-10-10          2024-10-12
# 97  X06n_fiSY10         2024-10-10          2024-10-12
# 95  vokTtGVd4Ls         2024-10-11          2024-10-12
# 94  a4mZAMnC9A0         2024-10-09          2024-10-12
#
#                   channel_id          channel_title  \
# 0   UCmse5JbKneJqVyerfhDVYvQ           UV Creations
# 98  UCbBWncD3X_dfXwxmj4KwJnA           Sidharrth TV
# 97  UC60YvD_EAsoU2lIcQdxwR1Q   Unni Vlogs Cinephile
# 95  UCebC4x5l2-PQxg46Ucv9CsA              Crazy XYZ
# 94  UCGp21DZk5nhuESgznCO9UiA  Veyilon Entertainment
#
#                                   channel_description     channel_custom_url  \
# 0   UV Creations, founded in 2012 by V Vamsikrishn...           @uvcreations
# 98  Official page of General Entertainment Channel...    @officialsidharthtv
# 97  Hi,\nThis is my personal YouTube channel aka o...             @unnivlogs
# 95  Hello Guys, We create and upload videos relate...              @crazyxyz
# 94  Veyilon Entertainment is an online entertainme...  @veyilonentertainment
#
#    channel_published_at channel_country  \
# 0   2014-04-10 16:49:33           India
# 98  2016-03-28 13:12:34           India
# 97  2011-08-14 13:16:02           India
# 95  2017-09-10 18:22:11           India
# 94  2018-01-13 21:47:00           India
#
#                                           video_title  ... video_like_count  \
# 0   VISHWAMBHARA Official Teaser | Megastar Chiran...  ...           236311
# 98  ସିନ୍ଦୂର ଖେଳ- Sindura Khela -Mega Serial Watch ...  ...            10648
# 97  Vettaiyan Review Malayalam | Unni Vlogs Cinephile  ...             4312
# 95  All Type of Sky Shot Stash + Testing | ये धमाक...  ...           133883
# 94  Usure Needhaney | EP-1 | Manikandan Mathumathi...  ...             6666
#
#    video_comment_count channel_view_count channel_subscriber_count  \
# 0                13573          744568146                  1570000
# 98                  39         7104279192                  9060000
# 97                 464           88100899                   379000
# 95               10128         9291689782                 31400000
# 94                 160          179446735                   886000
#
#    channel_have_hidden_subscribers channel_video_count  \
# 0                            False                1023
# 98                           False               22584
# 97                           False                1544
# 95                           False                1390
# 94                           False                 787
#
#    channel_localized_title                      channel_localized_description  \
# 0             UV Creations  UV Creations, founded in 2012 by V Vamsikrishn...
# 98            Sidharrth TV  Official page of General Entertainment Channel...
# 97    Unni Vlogs Cinephile  Hi,\nThis is my personal YouTube channel aka o...
# 95               Crazy XYZ  Hello Guys, We create and upload videos relate...
# 94   Veyilon Entertainment  Veyilon Entertainment is an online entertainme...
#
#     video_trending_country  days_to_trend
# 0                    India              0
# 98                   India              2
# 97                   India              2
# 95                   India              1
# 94                   India              3
#
# [5 rows x 29 columns]

# %%
like_th = df5["video_like_count"].median()
comment_th = df5["video_comment_count"].median()

# %%
df5["will_trend"] = (
    (df5["video_view_count"] >= 100_000) &
    (df5["video_like_count"] >= like_th) &
    (df5["video_comment_count"] >= comment_th)
).astype(int)

# %%
df5["will_trend"].value_counts()
df5["will_trend"].value_counts(normalize=True)
# Out:
# will_trend
# 0    0.620372
# 1    0.379628
# Name: proportion, dtype: float64

# %% [markdown]
# #### removing unnecessary columns

# %%
df5 = df5.drop(
    columns=[
        "channel_published_at",
        "channel_id",
        "channel_description",
        "channel_custom_url",
        "channel_published_at",
        "channel_country",
        "video_dimension",
        "video_definition",
        "video_view_count",
        "video_comment_count",
        "video_like_count",
        "channel_have_hidden_subscribers",
        "channel_localized_title",
        "channel_localized_description", 
        "video_default_thumbnail"
    ],
    errors="ignore"
)

# %%
df5.columns
# Out:
# Index(['video_id', 'video_published_at', 'video_trending_date',
#        'channel_title', 'video_title', 'video_description',
#        'video_category_id', 'video_tags', 'video_duration',
#        'video_licensed_content', 'channel_view_count',
#        'channel_subscriber_count', 'channel_video_count',
#        'video_trending_country', 'days_to_trend', 'will_trend'],
#       dtype='object')

# %%
df5.shape
# Out:
# (32329, 16)

# %%
df5['video_category_id'].sample(20)
# Out:
# 2656            Entertainment
# 24104                   Music
# 27098    Science & Technology
# 11438                  Gaming
# 62908                  Gaming
# 18700           Entertainment
# 46220                   Music
# 20393                  Sports
# 2313            Entertainment
# 513             Entertainment
# 1627            Entertainment
# 58615                  Gaming
# 67709          People & Blogs
# 47826                  Gaming
# 49827                   Music
# 39957                  Gaming
# 61273                   Music
# 10035          People & Blogs
# 60208                   Music
# 52373           Entertainment
# Name: video_category_id, dtype: object

# %%
df5['video_category_id'][1]
# Out:
# 'Music'

# %% [markdown]
# #### adding empty string at null values

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32329 entries, 0 to 71014
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   video_id                  32329 non-null  object
#  1   video_published_at        32329 non-null  datetime64[ns]
#  2   video_trending_date       32329 non-null  datetime64[ns]
#  3   channel_title             32329 non-null  object
#  4   video_title               32329 non-null  object
#  5   video_description         31429 non-null  object
#  6   video_category_id         32326 non-null  object
#  7   video_tags                26452 non-null  object
#  8   video_duration            32329 non-null  object
#  9   video_licensed_content    32329 non-null  bool
#  10  channel_view_count        32329 non-null  int64
#  11  channel_subscriber_count  32329 non-null  int64
#  12  channel_video_count       32329 non-null  int64
#  13  video_trending_country    32329 non-null  object
#  14  days_to_trend             32329 non-null  int64
#  15  will_trend                32329 non-null  int64
# dtypes: bool(1), datetime64[ns](2), int64(5), object(8)
# memory usage: 5.0+ MB

# %%
text_cols = [
    "video_description",
    "video_tags",
    "video_category_id",
]

df5[text_cols] = df5[text_cols].fillna("")

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32329 entries, 0 to 71014
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   video_id                  32329 non-null  object
#  1   video_published_at        32329 non-null  datetime64[ns]
#  2   video_trending_date       32329 non-null  datetime64[ns]
#  3   channel_title             32329 non-null  object
#  4   video_title               32329 non-null  object
#  5   video_description         32329 non-null  object
#  6   video_category_id         32329 non-null  object
#  7   video_tags                32329 non-null  object
#  8   video_duration            32329 non-null  object
#  9   video_licensed_content    32329 non-null  bool
#  10  channel_view_count        32329 non-null  int64
#  11  channel_subscriber_count  32329 non-null  int64
#  12  channel_video_count       32329 non-null  int64
#  13  video_trending_country    32329 non-null  object
#  14  days_to_trend             32329 non-null  int64
#  15  will_trend                32329 non-null  int64
# dtypes: bool(1), datetime64[ns](2), int64(5), object(8)
# memory usage: 5.0+ MB

# %%
df5.sample(10)
# Out:
#           video_id video_published_at video_trending_date       channel_title  \
# 14506  uDSY2YKOSO8         2025-01-30          2025-01-31           STAR भारत
# 1939   6YIof97N12E         2024-10-24          2024-10-26            Star Maa
# 13921  1xfVqb-E9L8         2025-01-26          2025-01-26        Reporter TV
# 11821  nnO1o6TYhaM         2025-01-07          2025-01-08           BANGTANTV
# 59714  8dpte6encp0         2025-11-09          2025-11-09            Badge 99
# 59521  5R3YF0fuZw4         2025-11-08          2025-11-08      YOGI BOLTA HAI
# 36149  cSnfIT95KXQ         2025-07-10          2025-07-10  Sourav Joshi Vlogs
# 54103  m3pCx5upjl0         2025-10-11          2025-10-11         Carry Depie
# 7656   1Cg8ssqnVVs         2024-12-05          2024-12-06    Vijay Television
# 63659  TuCTTCu0Rvg         2025-11-28          2025-11-29           Juke Dock
#
#                                              video_title  \
# 14506  Amrit Manthan | Kya Amrit ka plan ho jayega su...
# 1939   Bigg Boss Telugu 8 | Day 53 - Promo 3 | Clans ...
# 13921  റിപ്പബ്ലിക് ​ദിനാഘോഷ ചടങ്ങിനിടയിൽ ​കമ്മീഷണർ കു...
# 11821                            [달려라 석진] EP.16 | 나야, 좀비
# 59714  Giveaway Customs & Rank Push 🔥 Garena Free Fir...
# 59521  The Family Man S3 Trailer & Michael Teaser Rev...
# 36149                       Kunali Ne G-Wagon Khich Di 😲
# 54103              We Got Trapped In CUSTOM SKY BLOCK !!
# 7656   Pandian Stores 2 | 5th to 7th December 2024 - ...
# 63659  Together - Nirvair Pannu (Official Video) Deol...
#
#                                        video_description video_category_id  \
# 14506  Star Bharat Subscribe Now https://www.youtube....     Entertainment
# 1939   Both the clans in the Bigg Boss house are priv...    People & Blogs
# 13921  റിപ്പബ്ലിക് ​ദിനാഘോഷ ചടങ്ങിനിടയിൽ ​കമ്മീഷണർ കു...     Entertainment
# 11821  #RunJin #달려라석진 #진 #Jin \n\nConnect with BTS:\n...             Music
# 59714  Give me Any Challenge & I Will Complete it. | ...            Gaming
# 59521  The Family Man S3 Trailer Review by Yogi Bolta...     Entertainment
# 36149  #GalaxyZFold7\n#GalaxyAI\n#Samsung\n#PlayGalax...    People & Blogs
# 54103  in this video we got stuck in skyblock..\n\nDi...            Gaming
# 7656   பாண்டியன் ஸ்டோர்ஸ் தந்தை சொல் மிக்க மந்திரம் இ...     Entertainment
# 63659  JUKE DOCK Presents New Music Video TOGETHER By...             Music
#
#                                               video_tags video_duration  \
# 14506  star bharat,star bharat all serial,star bharat...       PT21M19S
# 1939   star maa,maa tv serials,maa tv serials promo,s...        PT1M17S
# 13921  arun kumar reporter tv,mv nikesh kumar reporte...        PT1M48S
# 11821  방탄소년단,BTS,BANGTAN,알엠,RM,슈가,SUGA,제이홉,jhope,지민,정...        PT28M6S
# 59714  free fire,badge99 live,ff live,badge99,top 1 g...     PT6H23M55S
# 59521  The Family Man S3,The Family Man Season 3,The ...        PT5M12S
# 36149  sourav joshi,sourav joshi vlogs,family vlogs,d...        PT8M11S
# 54103                     carry depie,minecraft,skyblock       PT18M17S
# 7656   Pandian Stores,Star,Star Vijay TV,Vijay TV,Vij...          PT40S
# 63659                                                           PT2M41S
#
#        video_licensed_content  channel_view_count  channel_subscriber_count  \
# 14506                    True         14330468636                  20500000
# 1939                     True         15445149966                  11200000
# 13921                    True            25243886                    148000
# 11821                    True         24161704347                  79600000
# 59714                    True          1923110136                  11800000
# 59521                    True           685221296                   1460000
# 36149                    True         17698640481                  34400000
# 54103                    True          1108365560                   3260000
# 7656                     True         47383148311                  25800000
# 63659                    True          2690140112                   5690000
#
#        channel_video_count video_trending_country  days_to_trend  will_trend
# 14506                46345                  India              1           0
# 1939                 60385                  India              2           1
# 13921                 4898                  India              0           0
# 11821                 2681                  India              1           1
# 59714                 1182                  India              0           0
# 59521                 1249                  India              0           1
# 36149                 2086                  India              0           1
# 54103                  450                  India              0           1
# 7656                122682                  India              1           1
# 63659                  657                  India              1           1

# %% [markdown]
# #### text preprocessing

# %%
import re
import string

def clean_text(q):
    if not isinstance(q, str):
        return ""

    # Lowercase
    q = q.lower()

    # Replace symbols with words
    q = q.replace('%', ' percent ')
    q = q.replace('$', ' doller ')
    q = q.replace('₹', ' rupee ')
    q = q.replace('€', ' euro ')
    q = q.replace('@', ' at ')

    # Remove emojis
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        "]+",
        flags=re.UNICODE
    )
    q = emoji_pattern.sub(r'', q)

    # Remove punctuation
    q = q.translate(str.maketrans('', '', string.punctuation))

    # Remove extra whitespace
    q = re.sub(r'\s+', ' ', q).strip()

    return q

# %%
df5["video_title"] = df5["video_title"].apply(clean_text) 
df5["video_description"] = df5["video_description"].apply(clean_text)
df5["video_tags"] = df5["video_tags"].apply(clean_text)
df5["channel_title"] = df5["channel_title"].apply(clean_text)
df5["video_category_id"] = df5["video_category_id"].apply(clean_text)
df5["video_trending_country"] = df5["video_trending_country"].apply(clean_text)

# %%
df5.head()
# Out:
#        video_id video_published_at video_trending_date          channel_title  \
# 0   NCv-wz1nSnE         2024-10-12          2024-10-12           uv creations
# 98  dBa1_GKAOAk         2024-10-10          2024-10-12           sidharrth tv
# 97  X06n_fiSY10         2024-10-10          2024-10-12   unni vlogs cinephile
# 95  vokTtGVd4Ls         2024-10-11          2024-10-12              crazy xyz
# 94  a4mZAMnC9A0         2024-10-09          2024-10-12  veyilon entertainment
#
#                                           video_title  \
# 0   vishwambhara official teaser megastar chiranje...
# 98  ସିନ୍ଦୂର ଖେଳ sindura khela mega serial watch mo...
# 97    vettaiyan review malayalam unni vlogs cinephile
# 95  all type of sky shot stash testing ये धमाकेदार...
# 94  usure needhaney ep1 manikandan mathumathi swaa...
#
#                                     video_description   video_category_id  \
# 0   vishwambhara official teaser on uv creations v...       entertainment
# 98  କାହିଁକି ହେଲା ଏ ବଜ୍ରପାତ ଭାଙ୍ଗିଦେଲା ଆଦ୍ୟା ଅଂଶଙ୍କ...       entertainment
# 97  click on the link to get exciting offers downl...       entertainment
# 95  hello guys is video me humne apko bahut mazeda...  science technology
# 94  usureneedhaney webseries tamilwebseries manika...              comedy
#
#                                            video_tags video_duration  \
# 0   vishwambhara official teasermegastar chiranjee...        PT1M33S
# 98  sidharth tvsidharthtvsidharth tv channelsidhar...         PT1M9S
# 97  unni vlogsunnivlogsunnivlogunni vlogs cinephil...        PT8M22S
# 95  2024 diwali stashdiwali stashcrazy xyz diwali ...       PT24M12S
# 94  veyilonveyilon entertainmentveliyonveylonveyli...       PT20M35S
#
#     video_licensed_content  channel_view_count  channel_subscriber_count  \
# 0                     True           744568146                   1570000
# 98                    True          7104279192                   9060000
# 97                    True            88100899                    379000
# 95                    True          9291689782                  31400000
# 94                    True           179446735                    886000
#
#     channel_video_count video_trending_country  days_to_trend  will_trend
# 0                  1023                  india              0           1
# 98                22584                  india              2           0
# 97                 1544                  india              2           0
# 95                 1390                  india              1           1
# 94                  787                  india              3           1

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32329 entries, 0 to 71014
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   video_id                  32329 non-null  object
#  1   video_published_at        32329 non-null  datetime64[ns]
#  2   video_trending_date       32329 non-null  datetime64[ns]
#  3   channel_title             32329 non-null  object
#  4   video_title               32329 non-null  object
#  5   video_description         32329 non-null  object
#  6   video_category_id         32329 non-null  object
#  7   video_tags                32329 non-null  object
#  8   video_duration            32329 non-null  object
#  9   video_licensed_content    32329 non-null  bool
#  10  channel_view_count        32329 non-null  int64
#  11  channel_subscriber_count  32329 non-null  int64
#  12  channel_video_count       32329 non-null  int64
#  13  video_trending_country    32329 non-null  object
#  14  days_to_trend             32329 non-null  int64
#  15  will_trend                32329 non-null  int64
# dtypes: bool(1), datetime64[ns](2), int64(5), object(8)
# memory usage: 5.0+ MB

# %%
df5.head()
# Out:
#        video_id video_published_at video_trending_date          channel_title  \
# 0   NCv-wz1nSnE         2024-10-12          2024-10-12           uv creations
# 98  dBa1_GKAOAk         2024-10-10          2024-10-12           sidharrth tv
# 97  X06n_fiSY10         2024-10-10          2024-10-12   unni vlogs cinephile
# 95  vokTtGVd4Ls         2024-10-11          2024-10-12              crazy xyz
# 94  a4mZAMnC9A0         2024-10-09          2024-10-12  veyilon entertainment
#
#                                           video_title  \
# 0   vishwambhara official teaser megastar chiranje...
# 98  ସିନ୍ଦୂର ଖେଳ sindura khela mega serial watch mo...
# 97    vettaiyan review malayalam unni vlogs cinephile
# 95  all type of sky shot stash testing ये धमाकेदार...
# 94  usure needhaney ep1 manikandan mathumathi swaa...
#
#                                     video_description   video_category_id  \
# 0   vishwambhara official teaser on uv creations v...       entertainment
# 98  କାହିଁକି ହେଲା ଏ ବଜ୍ରପାତ ଭାଙ୍ଗିଦେଲା ଆଦ୍ୟା ଅଂଶଙ୍କ...       entertainment
# 97  click on the link to get exciting offers downl...       entertainment
# 95  hello guys is video me humne apko bahut mazeda...  science technology
# 94  usureneedhaney webseries tamilwebseries manika...              comedy
#
#                                            video_tags video_duration  \
# 0   vishwambhara official teasermegastar chiranjee...        PT1M33S
# 98  sidharth tvsidharthtvsidharth tv channelsidhar...         PT1M9S
# 97  unni vlogsunnivlogsunnivlogunni vlogs cinephil...        PT8M22S
# 95  2024 diwali stashdiwali stashcrazy xyz diwali ...       PT24M12S
# 94  veyilonveyilon entertainmentveliyonveylonveyli...       PT20M35S
#
#     video_licensed_content  channel_view_count  channel_subscriber_count  \
# 0                     True           744568146                   1570000
# 98                    True          7104279192                   9060000
# 97                    True            88100899                    379000
# 95                    True          9291689782                  31400000
# 94                    True           179446735                    886000
#
#     channel_video_count video_trending_country  days_to_trend  will_trend
# 0                  1023                  india              0           1
# 98                22584                  india              2           0
# 97                 1544                  india              2           0
# 95                 1390                  india              1           1
# 94                  787                  india              3           1

# %%
df5[df5["will_trend"] == 0]
# Out:
#           video_id video_published_at video_trending_date  \
# 98     dBa1_GKAOAk         2024-10-10          2024-10-12
# 97     X06n_fiSY10         2024-10-10          2024-10-12
# 92     jnybkusldmY         2024-10-10          2024-10-12
# 91     kGnH4UN-IKs         2024-10-11          2024-10-12
# 90     xgCAxq5RRKo         2024-10-10          2024-10-12
# ...            ...                ...                 ...
# 71051  V9TBo3Wvz_k         2026-01-05          2026-01-05
# 71019  FKTJtSrZfMs         2026-01-05          2026-01-05
# 71020  HRatamZPHOQ         2026-01-04          2026-01-05
# 71021  x7prSYDUGu8         2026-01-04          2026-01-05
# 71014  HuB7MYuaGec         2026-01-05          2026-01-05
#
#                                   channel_title  \
# 98                                 sidharrth tv
# 97                         unni vlogs cinephile
# 92                                 sidharrth tv
# 91                               telly reporter
# 90                                basheer bashi
# ...                                         ...
# 71051                               black7plays
# 71019                                 jnk gamer
# 71020  kannada bhakti songs ಕನ್ನಡ ಭಕ್ತಿ ಹಾಡುಗಳು
# 71021                         tv9 entertainment
# 71014                              yippi gaming
#
#                                              video_title  \
# 98     ସିନ୍ଦୂର ଖେଳ sindura khela mega serial watch mo...
# 97       vettaiyan review malayalam unni vlogs cinephile
# 92     sindura nuhen khela ghara full episode 205 odi...
# 91     yeh rishta kya kehlata hai today episode new p...
# 90     a romantic candlelight dinner with suhana 🧚‍ s...
# ...                                                  ...
# 71051  alien attack in los santos – franklin learns t...
# 71019  franklin shinchan buy indian tata truck and st...
# 71020  ಸೋಮವಾರ ವಿಶೇಷ ಭಕ್ತಿಗೀತೆಗಳು ಲಿಂಗಷ್ಟಕಂ ಶಿವಾಷ್ಟಕಂ ...
# 71021  mana shankara vara prasad garu trailer launch ...
# 71014  shinchan and franklin tried the impossible ram...
#
#                                        video_description video_category_id  \
# 98     କାହିଁକି ହେଲା ଏ ବଜ୍ରପାତ ଭାଙ୍ଗିଦେଲା ଆଦ୍ୟା ଅଂଶଙ୍କ...     entertainment
# 97     click on the link to get exciting offers downl...     entertainment
# 92     sidharth tv ଏବେ ସମସ୍ତ dth ଏବଂ cabel ରେ ଉପଲବ୍ଧ ...     entertainment
# 91     star plus serial yrkkh yeh rishta kya kehlata ...     entertainment
# 90     bb1988 cosmetics order on whatsapp 8089680298 ...      people blogs
# ...                                                  ...               ...
# 71051  shinchan gta gta5 alien attack in los santos –...            gaming
# 71019  franklin shinchan buy indian tata truck and st...            gaming
# 71020  ಸೋಮವಾರ ವಿಶೇಷ ಭಕ್ತಿಗೀತೆಗಳು ಲಿಂಗಷ್ಟಕಂ ಶಿವಾಷ್ಟಕಂ ...             music
# 71021  mana shankara vara prasad garu trailer launch ...     entertainment
# 71014  shinchan and franklin tried the impossible ram...            gaming
#
#                                               video_tags video_duration  \
# 98     sidharth tvsidharthtvsidharth tv channelsidhar...         PT1M9S
# 97     unni vlogsunnivlogsunnivlogunni vlogs cinephil...        PT8M22S
# 92     sidharth tvsidharthtvsidharth tv channelsidhar...       PT22M35S
# 91     yeh rishta kya kehlata haiyeh rishta kya kehla...           PT1M
# 90                                                             PT17M12S
# ...                                                  ...            ...
# 71051  franklin shinchan new videosfranklin videosgta...       PT38M16S
# 71019  techno gamerzflight gamershinchan gta 5shincha...       PT27M11S
# 71020  lord shiva kannada songskannada shiva devotion...      PT1H5M23S
# 71021  tv9tv9 entertainmenttv9 ettelugu entertainment...     PT1H20M18S
# 71014  shinchanshinchan gta 5franklinfranklin shincha...       PT21M57S
#
#        video_licensed_content  channel_view_count  channel_subscriber_count  \
# 98                       True          7104279192                   9060000
# 97                       True            88100899                    379000
# 92                       True          7104279192                   9060000
# 91                       True          4462871439                   5980000
# 90                       True           635237121                   1280000
# ...                       ...                 ...                       ...
# 71051                    True           249862433                    808000
# 71019                    True           175055745                   1010000
# 71020                    True             1081503                      3990
# 71021                    True          3485144950                   2940000
# 71014                    True          2346149232                   6770000
#
#        channel_video_count video_trending_country  days_to_trend  will_trend
# 98                   22584                  india              2           0
# 97                    1544                  india              2           0
# 92                   22584                  india              2           0
# 91                   59059                  india              1           0
# 90                     738                  india              2           0
# ...                    ...                    ...            ...         ...
# 71051                  389                  india              0           0
# 71019                  820                  india              0           0
# 71020                   77                  india              1           0
# 71021                88939                  india              1           0
# 71014                 1721                  india              0           0
#
# [20056 rows x 16 columns]

# %%
df5["will_trend"].describe()
# Out:
# count    32329.000000
# mean         0.379628
# std          0.485302
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: will_trend, dtype: float64

# %% [markdown]
# #### decoding video_duration

# %%
# !pip install isodate
# Out:
# Requirement already satisfied: isodate in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (0.7.2)

# %%
import isodate

df5["video_duration_sec"] = df5["video_duration"].apply(
    lambda x: isodate.parse_duration(x).total_seconds()
)

# %%
df5 = df5.drop(columns=["video_duration"])

# %%
df5.head(1)
# Out:
#       video_id video_published_at video_trending_date channel_title  \
# 0  NCv-wz1nSnE         2024-10-12          2024-10-12  uv creations
#
#                                          video_title  \
# 0  vishwambhara official teaser megastar chiranje...
#
#                                    video_description video_category_id  \
# 0  vishwambhara official teaser on uv creations v...     entertainment
#
#                                           video_tags  video_licensed_content  \
# 0  vishwambhara official teasermegastar chiranjee...                    True
#
#    channel_view_count  channel_subscriber_count  channel_video_count  \
# 0           744568146                   1570000                 1023
#
#   video_trending_country  days_to_trend  will_trend  video_duration_sec
# 0                  india              0           1                93.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.kdeplot(df5['channel_view_count'], fill=True)
plt.xlabel("channel view count")
plt.title("KDE Plot of channel_view_count")
plt.show()

# %%
sns.kdeplot(df5['channel_subscriber_count'], fill=True)
plt.xlabel("channel subscriber count")
plt.title("KDE Plot of channel_subscriber_count")
plt.show()

# %%
sns.kdeplot(df5['channel_video_count'], fill=True)
plt.xlabel("channel_video_count")
plt.title("KDE Plot of channel_video_count")
plt.show()

# %%
sns.countplot(
    data=df5,
    x='video_licensed_content'
)

plt.xticks(rotation=90)
plt.title("Count video_licensed_content")
plt.show()

# %%
df5['video_licensed_content'].value_counts()
# Out:
# video_licensed_content
# True     30698
# False     1631
# Name: count, dtype: int64

# %% [markdown]
# #### removing those rows which has video_licensed_content == 0

# %%
df5 = df5[df5['video_licensed_content'] == True]

# %%
df5.shape
# Out:
# (30698, 16)

# %%
df5 = df5.drop(columns=['video_licensed_content'])

# %%
df5.shape
# Out:
# (30698, 15)

# %% [markdown]
# #### applying log transform for channel_view_count	channel_subscriber_count	channel_video_count

# %%
df5["log_channel_subscriber_count"] = np.log1p(df5["channel_subscriber_count"])
df5["log_channel_video_count"] = np.log1p(df5["channel_video_count"])
df5["log_channel_view_count"] = np.log1p(df5["channel_view_count"])

# %%
df5 = df5.drop(columns=[
    "channel_subscriber_count",
    "channel_video_count",
    "channel_view_count"
])

# %%
df5.describe()
# Out:
#                   video_published_at            video_trending_date  \
# count                          30698                          30698
# mean   2025-07-12 19:13:31.753208832  2025-07-13 15:12:56.102677504
# min              2024-10-05 00:00:00            2024-10-12 00:00:00
# 25%              2025-04-04 00:00:00            2025-04-05 00:00:00
# 50%              2025-08-16 00:00:00            2025-08-17 00:00:00
# 75%              2025-10-25 00:00:00            2025-10-26 00:00:00
# max              2026-01-05 00:00:00            2026-01-05 00:00:00
# std                              NaN                            NaN
#
#        days_to_trend    will_trend  video_duration_sec  \
# count   30698.000000  30698.000000        30698.000000
# mean        0.832921      0.381751         2233.267737
# min         0.000000      0.000000            5.000000
# 25%         0.000000      0.000000          257.000000
# 50%         1.000000      0.000000          810.000000
# 75%         1.000000      1.000000         1789.750000
# max        29.000000      1.000000        45426.000000
# std         1.315099      0.485824         4422.261180
#
#        log_channel_subscriber_count  log_channel_video_count  \
# count                  30698.000000             30698.000000
# mean                      14.049493                 7.047378
# min                        1.386294                 0.000000
# 25%                       12.751303                 5.641907
# 50%                       14.272936                 6.813445
# 75%                       15.852827                 8.097350
# max                       19.843789                13.313914
# std                        2.558745                 2.349934
#
#        log_channel_view_count
# count            30698.000000
# mean                19.724642
# min                  0.000000
# 25%                 18.009452
# 50%                 19.905550
# 75%                 21.682219
# max                 26.508687
# std                  3.068515

# %%
df5[df5['log_channel_video_count']==0]
# Out:
#           video_id video_published_at video_trending_date  \
# 38235  sgkqebn9Wyk         2025-07-22          2025-07-23
# 39401  Q0u58lP_3F4         2025-07-28          2025-07-29
# 48638  EXoYeewJB6Q         2025-09-12          2025-09-13
# 52909  AqUonMjxaog         2025-10-04          2025-10-05
# 58449  EpjFSOJjmEw         2025-10-27          2025-11-02
# 60218  NAEZMzVVw2s         2025-11-11          2025-11-11
# 62755  H6J6R7fuLhw         2025-11-22          2025-11-24
# 63477  5VE9x0DLXvo         2025-11-28          2025-11-29
#
#                       channel_title  \
# 38235  akshay kumar chitaruwa topic
# 39401      sandeep thulasidas topic
# 48638              jharkhandi beats
# 52909             zubeen garg topic
# 58449                     mac music
# 60218                 release topic
# 62755             mahbub khan topic
# 63477                 release topic
#
#                                              video_title  \
# 38235                          chitharuwa chalal devghar
# 39401                   baava theme song from su from so
# 48638  video साड़ी नीला नीला paras raj yadav sadi nil...
# 52909                               mayabini ratir bukut
# 58449  रंगदारीगाना राइफल से खुटा ठोकाला tuntunyadav r...
# 60218                                    always the same
# 62755                           tere dil ki awaj hun mai
# 63477                                             barota
#
#                                        video_description video_category_id  \
# 38235  provided to youtube by st digital llp chitharu...             music
# 39401  provided to youtube by lighter buddha films ba...             music
# 48638  audiovideo credits video साड़ी नीला नीला paras...      people blogs
# 52909  provided to youtube by tunecore mayabini ratir...             music
# 58449  रंगदारीगाना राइफल से खुटा ठोकाला tuntunyadav r...      people blogs
# 60218  provided to youtube by panjaab records always ...             music
# 62755  provided to youtube by ditto music tere dil ki...             music
# 63477  provided to youtube by ditto music barota · si...             music
#
#                                               video_tags  \
# 38235    akshay kumar chitaruwachitharuwa chalal devghar
# 39401  sandeep thulasidasraj b shettybaava theme song...
# 48638  साड़ी नीला नीलाparas raj yadavsadi nila nilasa...
# 52909                    zubeen gargmayabini ratir bukut
# 58449  tuntunyadavराइफल से खुटा ठोकालाraifal se khuta...
# 60218                       arjan dhillonalways the same
# 62755                mahbub khantere dil ki awaj hun mai
# 63477                     sidhu moose walathe kiddbarota
#
#       video_trending_country  days_to_trend  will_trend  video_duration_sec  \
# 38235                  india              1           0               270.0
# 39401                  india              1           0                46.0
# 48638                  india              1           0               215.0
# 52909                  india              1           0               323.0
# 58449                  india              6           0               302.0
# 60218                  india              0           0               155.0
# 62755                  india              2           0               418.0
# 63477                  india              1           1               244.0
#
#        log_channel_subscriber_count  log_channel_video_count  \
# 38235                      7.714677                      0.0
# 39401                      5.147494                      0.0
# 48638                      5.958425                      0.0
# 52909                      6.016157                      0.0
# 58449                      6.214608                      0.0
# 60218                      3.713572                      0.0
# 62755                      5.170484                      0.0
# 63477                      5.894403                      0.0
#
#        log_channel_view_count
# 38235               10.130902
# 39401               10.268547
# 48638                8.444407
# 52909               11.634346
# 58449               11.166257
# 60218                0.000000
# 62755                0.000000
# 63477               14.079774

# %%
fig,ax = plt.subplots(nrows=2, ncols=2,figsize=(10,10))
sns.kdeplot(df5['log_channel_subscriber_count'], fill=True,ax=ax[0,0])
ax[0, 0].set_title("Log Channel Subscriber Count")
sns.kdeplot(df5['log_channel_video_count'], fill=True,ax=ax[0,1])
ax[0, 1].set_title("Log Channel Video Count")
sns.kdeplot(df5['log_channel_view_count'], fill=True,ax=ax[1,0])
ax[1, 0].set_title("log channel view count")
fig.delaxes(ax[1, 1])

plt.tight_layout()
fig.show()
# Out:
# C:\Users\AKSHAY KUMAR\AppData\Local\Temp\ipykernel_23332\3064498936.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
g=sns.PairGrid(data=df5,hue='will_trend')
g.map_diag(sns.kdeplot) 
g.map_offdiag(sns.scatterplot)

# %%
from sklearn.model_selection import train_test_split

X = df5[["video_title","video_description","video_category_id","video_tags","video_trending_country","video_duration_sec","log_channel_subscriber_count","log_channel_video_count","log_channel_view_count"]]
y = df5["will_trend"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
X_train.shape
# Out:
# (24558, 9)

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.1.0)
# Requirement already satisfied: networkx in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
from sentence_transformers import SentenceTransformer

embedder = SentenceTransformer(
    "paraphrase-multilingual-MiniLM-L12-v2",
     device="cuda"
)

# %%
X_train_desc_texts = (
    X_train["video_description"]
    .astype(str)
    .str.strip()
)

X_test_desc_texts = (
    X_test["video_description"]
    .astype(str)
    .str.strip()
)

# %%
X_train_title_texts = (
    X_train["video_title"]
    .astype(str)
    .str.strip()
)

X_test_title_texts = (
    X_test["video_title"]
    .astype(str)
    .str.strip()
)

# %%
X_train_tags_texts = (
    X_train["video_tags"]
    .astype(str)
    .str.strip()
)

X_test_tags_texts = (
    X_test["video_tags"]
    .astype(str)
    .str.strip()
)

# %%
X_train_cat_texts = (
    X_train["video_category_id"]
    .astype(str)
    .str.lower()
    .str.strip()
)

X_test_cat_texts = (
    X_test["video_category_id"]
    .astype(str)
    .str.lower()
    .str.strip()
)

# %%
# Description embeddings
X_train_desc_emb = embedder.encode(
    X_train_desc_texts.tolist(),
    batch_size=256,
    show_progress_bar=True
)

X_test_desc_emb = embedder.encode(
    X_test_desc_texts.tolist(),
    batch_size=256,
    show_progress_bar=True
)

# Title embeddings
X_train_title_emb = embedder.encode(
    X_train_title_texts.tolist(),
    batch_size=256,
    show_progress_bar=True
)

X_test_title_emb = embedder.encode(
    X_test_title_texts.tolist(),
    batch_size=256,
    show_progress_bar=True
)

# Tags embeddings
X_train_tags_emb = embedder.encode(
    X_train_tags_texts.tolist(),
    batch_size=256,
    show_progress_bar=True
)

X_test_tags_emb = embedder.encode(
    X_test_tags_texts.tolist(),
    batch_size=256,
    show_progress_bar=True
)
X_train_cat_emb = embedder.encode(
    X_train_cat_texts.tolist(),
    batch_size=256,
    show_progress_bar=True
)

X_test_cat_emb = embedder.encode(
    X_test_cat_texts.tolist(),
    batch_size=256,
    show_progress_bar=True
)
# Out:
# Batches:   0%|          | 0/96 [00:00<?, ?it/s]
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# Batches:   0%|          | 0/96 [00:00<?, ?it/s]
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# Batches:   0%|          | 0/96 [00:00<?, ?it/s]
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# Batches:   0%|          | 0/96 [00:00<?, ?it/s]
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
desc_cols  = [f"desc_emb_{i}" for i in range(X_train_desc_emb.shape[1])]
title_cols = [f"title_emb_{i}" for i in range(X_train_title_emb.shape[1])]
tags_cols  = [f"tags_emb_{i}" for i in range(X_train_tags_emb.shape[1])]
cat_emb_cols = [f"cat_emb_{i}" for i in range(X_train_cat_emb.shape[1])]

X_train_desc_df  = pd.DataFrame(X_train_desc_emb,  columns=desc_cols,  index=X_train.index)
X_test_desc_df   = pd.DataFrame(X_test_desc_emb,   columns=desc_cols,  index=X_test.index)

X_train_title_df = pd.DataFrame(X_train_title_emb, columns=title_cols, index=X_train.index)
X_test_title_df  = pd.DataFrame(X_test_title_emb,  columns=title_cols, index=X_test.index)

X_train_tags_df  = pd.DataFrame(X_train_tags_emb,  columns=tags_cols,  index=X_train.index)
X_test_tags_df   = pd.DataFrame(X_test_tags_emb,   columns=tags_cols,  index=X_test.index)

X_train_cat_df = pd.DataFrame(
    X_train_cat_emb,
    columns=cat_emb_cols,
    index=X_train.index
)

X_test_cat_df = pd.DataFrame(
    X_test_cat_emb,
    columns=cat_emb_cols,
    index=X_test.index
)

# %%
X_test_tags_df.shape
# Out:
# (6140, 384)

# %%
X_train = pd.concat(
    [X_train, X_train_desc_df, X_train_title_df, X_train_tags_df,X_train_cat_df],
    axis=1
)

X_test = pd.concat(
    [X_test, X_test_desc_df, X_test_title_df, X_test_tags_df,X_test_cat_df],
    axis=1
)


X_train = X_train.drop(
    columns=["video_description", "video_title", "video_tags","video_category_id","video_trending_country"]
)

X_test = X_test.drop(
    columns=["video_description", "video_title", "video_tags","video_category_id","video_trending_country"]
)

# %%
X_train.shape
# Out:
# (24558, 1540)

# %%
X_train.columns
# Out:
# Index(['video_duration_sec', 'log_channel_subscriber_count',
#        'log_channel_video_count', 'log_channel_view_count', 'desc_emb_0',
#        'desc_emb_1', 'desc_emb_2', 'desc_emb_3', 'desc_emb_4', 'desc_emb_5',
#        ...
#        'cat_emb_374', 'cat_emb_375', 'cat_emb_376', 'cat_emb_377',
#        'cat_emb_378', 'cat_emb_379', 'cat_emb_380', 'cat_emb_381',
#        'cat_emb_382', 'cat_emb_383'],
#       dtype='object', length=1540)

# %%
numeric_features = [
    "video_duration_sec",
    "log_channel_view_count",
    "log_channel_subscriber_count",
    "log_channel_video_count"
]

# %%
embedding_features = sorted([
    col for col in X_train.columns
    if col.startswith((
        "desc_emb_",
        "title_emb_",
        "tags_emb_",
        "cat_emb_"
    ))
])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("emb", "passthrough", embedding_features),
    ]
)

# %%
X_train["log_channel_subscriber_count"] = X_train["log_channel_subscriber_count"].clip(-2.5, 2.5)
X_test["log_channel_subscriber_count"]  = X_test["log_channel_subscriber_count"].clip(-2.5, 2.5)

X_train["log_channel_view_count"] = X_train["log_channel_view_count"].clip(-2.5, 2.5)
X_test["log_channel_view_count"]  = X_test["log_channel_view_count"].clip(-2.5, 2.5)

# %%
from xgboost import XGBClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    class_weight="balanced",
    n_estimators=300,
    max_depth=None,          # or try 20–40
    min_samples_split=5,
    min_samples_leaf=2,
    max_features="sqrt",     # VERY important for embeddings
    n_jobs=-1,
    random_state=42
)

# %%
from sklearn.pipeline import Pipeline

model = Pipeline( 
    steps=[ ("preprocess", preprocessor),
            ("clf", LogisticRegression(
                max_iter=1000,
                class_weight="balanced",
                n_jobs=-1
            )
            ) 
          ]
)

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\AKSHAY KUMAR\Desktop\aasf project\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['video_duration_sec',
#                                                    'log_channel_view_count',
#                                                    'log_channel_subscriber_count',
#                                                    'log_channel_video_count']),
#                                                  ('emb', 'passthrough',
#                                                   ['cat_emb_0', 'cat_emb_1',
#                                                    'cat_emb_10', 'cat_emb_100',
#                                                    'cat_emb_101', 'cat_emb_102',
#                                                    'cat_emb_103', 'cat_emb_104',
#                                                    'cat_emb_105', 'cat_emb_106',
#                                                    '...'cat_emb_108',
#                                                    'cat_emb_109', 'cat_emb_11',
#                                                    'cat_emb_110', 'cat_emb_111',
#                                                    'cat_emb_112', 'cat_emb_113',
#                                                    'cat_emb_114', 'cat_emb_115',
#                                                    'cat_emb_116', 'cat_emb_117',
#                                                    'cat_emb_118', 'cat_emb_119',
#                                                    'cat_emb_12', 'cat_emb_120',
#                                                    'cat_emb_121', 'cat_emb_122',
#                                                    'cat_emb_123', 'cat_emb_124', ...])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     n_jobs=-1))])

# %%
from sklearn.metrics import classification_report, roc_auc_score

y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84      3796
#            1       0.72      0.80      0.76      2344
#
#     accuracy                           0.80      6140
#    macro avg       0.79      0.80      0.80      6140
# weighted avg       0.81      0.80      0.81      6140
#
# ROC-AUC: 0.8862751162531424

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\akshay kumar\desktop\aasf project\venv\lib\site-packages (1.5.3)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\AKSHAY KUMAR\\Desktop\\aasf project\\accessing_from_databse'

# %%
import pickle

with open("youtube_trending_classifier.pkl", "wb") as f:
    pickle.dump(model, f)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
user_input = {
    "video_title": 'vishwambhara official teaser megastar chiranjeevi trisha krishnan vassishta mm keeravaani',
    "video_description": (
        'vishwambhara official teaser on uv creations vishwambhara is the latest telugu movie starring megastar chiranjeevi trisha krishnan and others directed by vassishta music by mm keeravaani and produced by uv creations vishwambharateaser thevishwambhara chiranjeevi megastarchiranjeevi trishakrishnan vassishta mmkeeravani uvcreations vishwambhara vishwambharamovie konidelachiranjeevi vishwambharatrailer latesttelugumovie latesttelugutrailers movie details movie name vishwambhara cast megastar chiranjeevi trisha krishnan technical crew writer director vassishta producers vamsi pramod vikram banner uv creations music mm keeravaani dop chota k naidu production designer as prakash costume designer sushmita konidela editor kotagiri venkateswara rao santhosh kamireddy dialogues sai madhav burra lyrics sri siva shakthi datta and chandrabose script associates srinivas gavireddy ganta sridhar nimmagadda srikanth and mayukh adithya exproducer karthik sabareesh line producer ramireddy sridhar reddy pro vamsishekar marketing first show publicity designs padma sri ads ananth kancherla click here to watch maa nanna super hero trailer httpswwwyoutubecomwatchvugv5i7yopre bhaje vaayu vegam trailer httpsyoutubeq0kqt1hkine bhaje vaayu vegam teaser httpsyoutubecjtimki7jbg bhaje vaayu vegam teaser launch by megastar chiranjeevi httpsyoutubepxogb76kgq vishwambhara title reveal concept video httpsyoutube0ho0vuay4q vishwambhara pooja ceremony httpsyoutubelibj42dx1ds follow for more updates about uv creations like httpswwwfacebookcomuvcthemoviemakers follow httpswwwinstagramcomuvcreationsofficial follow httpstwittercomuvcreations subscribe httpswwwyoutubecomcuvcreations'
    ),
    "video_tags": 'vishwambhara official teasermegastar chiranjeevitrisha krishnanvassishtamm keeravaanivishwambharateaserthevishwambharachiranjeeviuvcreationschiranjeevi new moviechiranjeevi lastest moviemegastar chiranjeevi new movie teaserlatest teasers 2024trisha new movie teaserlatest telugu movies 20242024 new moviesmegastar latest movieskonidela chiranjeevivassishta latest movieskeeravaani songschiranjeevi vishwambharatrisha latest movie',
    "video_category_id": 'entertainment',
    "video_duration_sec": 93,
    "channel_subscriber_count": 7.115300e+04,
    "channel_video_count": 71153.000000,
    "channel_view_count": 7.115300e+04
}

# %%
import numpy as np
import pandas as pd

user_input["log_channel_subscriber_count"] = np.log1p(
    user_input.pop("channel_subscriber_count")
)
user_input["log_channel_video_count"] = np.log1p(
    user_input.pop("channel_video_count")
)
user_input["log_channel_view_count"] = np.log1p(
    user_input.pop("channel_view_count")
)

X_user = pd.DataFrame([user_input])

# %%
desc_emb = embedder.encode(
    X_user["video_description"].astype(str).tolist()
)

title_emb = embedder.encode(
    X_user["video_title"].astype(str).tolist()
)

tags_emb = embedder.encode(
    X_user["video_tags"].astype(str).tolist()
)

cat_emb = embedder.encode(
    X_user["video_category_id"].astype(str).tolist()
)

# %%
desc_cols  = [f"desc_emb_{i}" for i in range(desc_emb.shape[1])]
title_cols = [f"title_emb_{i}" for i in range(title_emb.shape[1])]
tags_cols  = [f"tags_emb_{i}" for i in range(tags_emb.shape[1])]
cat_cols   = [f"cat_emb_{i}"  for i in range(cat_emb.shape[1])]

desc_df  = pd.DataFrame(desc_emb,  columns=desc_cols,  index=X_user.index)
title_df = pd.DataFrame(title_emb, columns=title_cols, index=X_user.index)
tags_df  = pd.DataFrame(tags_emb,  columns=tags_cols,  index=X_user.index)
cat_df   = pd.DataFrame(cat_emb,   columns=cat_cols,   index=X_user.index)

# %%
X_user = pd.concat(
    [X_user, desc_df, title_df, tags_df, cat_df],
    axis=1
)

# %%
X_user = X_user.drop(
    columns=[
        "video_description",
        "video_title",
        "video_tags",
        "video_category_id"
    ]
)

# %%
X_user
# Out:
#    video_duration_sec  log_channel_subscriber_count  log_channel_video_count  \
# 0                  93                     11.172602                11.172602
#
#    log_channel_view_count  desc_emb_0  desc_emb_1  desc_emb_2  desc_emb_3  \
# 0               11.172602   -0.143802   -0.238695   -0.070067   -0.117994
#
#    desc_emb_4  desc_emb_5  ...  cat_emb_374  cat_emb_375  cat_emb_376  \
# 0    0.061195      0.2187  ...     0.444259    -0.110336     0.353085
#
#    cat_emb_377  cat_emb_378  cat_emb_379  cat_emb_380  cat_emb_381  \
# 0     0.748383     -0.12731     0.248383     0.119396    -0.344952
#
#    cat_emb_382  cat_emb_383
# 0    -0.314642     0.057724
#
# [1 rows x 1540 columns]

# %%
prob = model.predict_proba(X_user)[0][1]

# %%
prediction = int(prob >= 0.5)

# %%
print(f"Trending Probability: {prob*100:.2f}%")

if prob >= 0.7:
    label = "High chance to trend 🚀"
elif prob >= 0.4:
    label = "Moderate chance to trend ⚠️"
else:
    label = "Low chance to trend ❌"

print(label)
# Out:
# Trending Probability: 100.00%
# High chance to trend 🚀

# %%
X_train.columns
# Out:
# Index(['video_trending_country', 'video_duration_sec',
#        'log_channel_subscriber_count', 'log_channel_video_count',
#        'log_channel_view_count', 'desc_emb_0', 'desc_emb_1', 'desc_emb_2',
#        'desc_emb_3', 'desc_emb_4',
#        ...
#        'cat_emb_374', 'cat_emb_375', 'cat_emb_376', 'cat_emb_377',
#        'cat_emb_378', 'cat_emb_379', 'cat_emb_380', 'cat_emb_381',
#        'cat_emb_382', 'cat_emb_383'],
#       dtype='object', length=1541)

# %%
import numpy as np

clf = model.named_steps["clf"]
feature_names = model.named_steps["preprocess"].get_feature_names_out()

coef_df = (
    pd.DataFrame({
        "feature": feature_names,
        "coef": clf.coef_[0]
    })
    .assign(abs_coef=lambda x: x["coef"].abs())
    .sort_values("abs_coef", ascending=False)
)

coef_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[233], line 9
#       3 clf = model.named_steps["clf"]
#       4 feature_names = model.named_steps["preprocess"].get_feature_names_out()
#       6 coef_df = (
#       7     pd.DataFrame({
#       8         "feature": feature_names,
# ----> 9         "coef": clf.coef_[0]
#      10     })
#      11     .assign(abs_coef=lambda x: x["coef"].abs())
#      12     .sort_values("abs_coef", ascending=False)
#      13 )
#      15 coef_df.head(20)
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'coef_'

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import roc_auc_score, make_scorer

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
scoring = {
    "roc_auc": "roc_auc",
    "f1": "f1",
    "accuracy": "accuracy"
}

# %%
cv_results = cross_validate(
    model,
    X,          # full feature dataframe
    y,          # target (will_trend)
    cv=cv,
    scoring=scoring,
    n_jobs=-1,
    return_train_score=True
)

# %%
import pandas as pd
import numpy as np

cv_df = pd.DataFrame(cv_results)

summary = pd.DataFrame({
    "Metric": ["ROC-AUC", "F1", "Accuracy"],
    "Train Mean": [
        cv_df["train_roc_auc"].mean(),
        cv_df["train_f1"].mean(),
        cv_df["train_accuracy"].mean()
    ],
    "Validation Mean": [
        cv_df["test_roc_auc"].mean(),
        cv_df["test_f1"].mean(),
        cv_df["test_accuracy"].mean()
    ],
    "Validation Std": [
        cv_df["test_roc_auc"].std(),
        cv_df["test_f1"].std(),
        cv_df["test_accuracy"].std()
    ]
})

summary

# %%
import numpy as np

clf = model.named_steps["clf"]
feature_names = model.named_steps["preprocess"].get_feature_names_out()

coef = clf.coef_[0]
top = sorted(
    zip(feature_names, coef),
    key=lambda x: abs(x[1]),
    reverse=True
)[:15]

for f, c in top:
    print(f, round(c, 4))

# %%
clf = model.named_steps["clf"]
print("Intercept:", clf.intercept_)

# %%
z = model.decision_function(X_user)
print("Logit score:", z)
print("Probability:", model.predict_proba(X_user)[0][1])

# %%
# !pip install xgboost

# %%
df5.head(1)
# Out:
#       video_id video_published_at video_trending_date channel_title  \
# 0  NCv-wz1nSnE         2024-10-12          2024-10-12  uv creations
#
#                                          video_title  \
# 0  vishwambhara official teaser megastar chiranje...
#
#                                    video_description video_category_id  \
# 0  vishwambhara official teaser on uv creations v...     entertainment
#
#                                           video_tags video_trending_country  \
# 0  vishwambhara official teasermegastar chiranjee...                  india
#
#    days_to_trend  will_trend  video_duration_sec  \
# 0              0           1                93.0
#
#    log_channel_subscriber_count  log_channel_video_count  \
# 0                     14.266587                 6.931472
#
#    log_channel_view_count
# 0               20.428315

# %%
df5.iloc[0,7]
# Out:
# 'vishwambhara official teasermegastar chiranjeevitrisha krishnanvassishtamm keeravaanivishwambharateaserthevishwambharachiranjeeviuvcreationschiranjeevi new moviechiranjeevi lastest moviemegastar chiranjeevi new movie teaserlatest teasers 2024trisha new movie teaserlatest telugu movies 20242024 new moviesmegastar latest movieskonidela chiranjeevivassishta latest movieskeeravaani songschiranjeevi vishwambharatrisha latest movie'
